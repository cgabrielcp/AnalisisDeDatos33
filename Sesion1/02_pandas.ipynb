# %% [markdown]
# # pandas

# %%
# instalar
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 24.1 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 33.5 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# instalar
import pandas as pd

# lista
# Diccionar

data = [['Juan', 25], ['Pedro', 25], ['Luis', 25]]

print(data)

df = pd.DataFrame(data, columns = ['Nombre', 'Edad'])
df
# Out:
# [['Juan', 25], ['Pedro', 25], ['Luis', 25]]
#   Nombre  Edad
# 0   Juan    25
# 1  Pedro    25
# 2   Luis    25

# %%
# Crear desde Diccionario
data = {
    'Nombre': ['Juan', 'Pedro', 'Luis'],
    'Edad': [25, 26, 25]
}

df_1 = pd.DataFrame(data)

df_1
# Out:
#   Nombre  Edad
# 0   Juan    25
# 1  Pedro    26
# 2   Luis    25
