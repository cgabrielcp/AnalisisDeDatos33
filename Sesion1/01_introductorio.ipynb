# %% [markdown]
# # Mi Primer Entorno python

# %%
# Este comentario inline

# %%
# Este es un bloque de registro
print('Primero Codigo')
print('Primero Codigo')
print('Primero Codigo')
print('Primero Codigo')

# %%
# Valdiacion de Numeros
if 2 < 3:
    print('2 es menor que 3')
    print('2 es menor que 3')
# Out:
# 2 es menor que 3
# 2 es menor que 3

# %%
def function():
    """
        Devuelve el dia seman
        Argunentos:
            -
            -
        Salida:
            -
    """
    return 1

# %%
print('Hola Mundo')
# Out:
# Hola Mundo
